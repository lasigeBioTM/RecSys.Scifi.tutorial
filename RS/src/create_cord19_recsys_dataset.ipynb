# %% [markdown]
# ## This module create CORD-19 corpus dataset as <user, item, rating, item_name, year> and <user_id, author_name>. The items should be defined by user

# %% [markdown]
# ### 1. import libraries

# %%
import pandas as pd
import sys
import json
import numpy as np
import time
from datetime import date, datetime

# %%
### 2. import user-defined-functions

# %%
from utils import *
from utils2json import *
from functions import *
from utils2ontologies import *
from utils2pubmed import *

# %%
pd.set_option('display.max_columns', None)
pd.set_option("max_rows", None)

# %% [markdown]
# ### get authors name from .csv file

# %%
def get_authors_metadata(data, label, ident):
    
    authors = data[data.label == ident].authors.values[0].split(';')
    for a in authors:
        a = a.split(',')
        first = unidecode.unidecode( ''.join(m for m in a[1] if m.isalpha()))
        last = unidecode.unidecode( ''.join(m for m in a[0] if m.isalpha()))
    return first + ', '+  last

# %% [markdown]
# ### entities defined by user

# %%
# if entities is defined by user then saved it in a list
active_lexicons = []
is_chebi, is_do, is_go, is_hp = True, True, False, False

active_lexicons.append('chebi')   
active_lexicons.append('do')

# %% [markdown]
# #### Path from original' json and entities' json folder, blacklist and metadata

# %%
original_json_folder = '../data/comm_use_subset/'
entities_json_folder = '../data/comm_use_subset_entities/'
path_to_blacklist = '../data/blacklist/blacklist_articles.txt'
path_to_metadata = '../data/metadata_new.csv'

# %%
entities_list_of_json_files = list_files_in_directory(path=entities_json_folder)
print(entities_list_of_json_files)
# Out:
# ['81c92759c804f01629de5c8499535a5b300b5f16_entities.json', 'PMC6275129_entities.json', '06ced00a5fc04215949aa72528f2eeaae1d58927_entities.json', '.ipynb_checkpoints', 'PMC446188_entities.json', 'cdb29ec7a9029d22f6fbf7ee04543819591acdc2_entities.json']

# %% [markdown]
# ##### Get all articles id that cannot be considered in use case

# %%
articles_blacklist = get_blacklist(file=path_to_blacklist)
print(articles_blacklist)

metadata = pd.read_csv(path_to_metadata)
# Out:
# ['cdb29ec7a9029d22f6fbf7ee04543819591acdc2\n', '.ipynb_checkpoints\n', 'cdb29ec7a9029d22f6fbf7ee04543819591acdc2\n', '.ipynb_checkpoints\n', '81c92759c804f01629de5c8499535a5b300b5f16']

# %%
user_item_rating_all = []
count = 0
#entities_list_of_json_files=['PMC7176216_entities.json']
for file in entities_list_of_json_files:
    # ## Exception
    if file.replace('_entities.json','') in articles_blacklist:
        continue
    # if file.startswith('PMC'):
    #     continue    
    print(count, "-", len(entities_list_of_json_files))            
    print(file)
        
    # check valid json file, i.e. contains values
    try:
        j_file_entities = open_json_file_pd(path=entities_json_folder, file=file)           
    except Exception as e:
        print(f'Json file does not contain values. Error message {e}')
        set_blacklist(file=path_to_blacklist, line=file.replace('_entities.json',''))
        continue
    
    df_entities = get_entities_id(get_entities(j_file_entities))
    if df_entities.empty:
        print(f'Json file does not contain values.')
        set_blacklist(file=path_to_blacklist, line=file.replace('_entities.json',''))
        continue    
    
    print(df_entities)
    article_id = get_article_id(j_file_entities)
    
    # check valid json file, i.e. contains values
    try:
        j_file_original = open_json_file(path=original_json_folder, file=article_id)
        #print(j_file_original)
    except Exception as e:
        print(f'Original json file does not exist. Error message {e}')
        set_blacklist(file=path_to_blacklist, line=file.replace('_entities.json',''))
        continue    
    
    # check if json file contains authors, otherwise try to find them in metadata.csv
    # if value remains null them put this article in the blacklist file
    list_of_authors = get_authors_names(data=j_file_original)
    
###  ---- Metadata ----
    # Some datas return an array, then we convert to a list and get first element
    publish_date=''      
    if article_id.startswith('PMC'):
        try:
            publish_date = metadata[metadata.pmcid == article_id].\
                publish_time.map(lambda v: v.split('-')[0]).tolist()[0]
        except Exception as e:    
            try:
                print(f'Find publish date, now with metapub. Error message {e}')            
                publish_date = get_year_by_metapub(pmcid=article_id) 
            except Exception as e: 
                try:                    
                    print(f'Find publish date, now with Bio. Error message {e}') 
                    pmid = get_pmid(pmcid=article_id) 
                    publish_date = get_year_by_bio(pmid) 
                except Exception as e:
                    print(f'Find publish date, now with metapub. Error message {e}')    
                
        finally:
            pass                                         
    else:
        try:
            publish_date = metadata[metadata.sha == article_id].\
                publish_time.map(lambda v: v.split('-')[0]).tolist()[0]
        finally:
            pass  

    print(publish_date)
    if publish_date==None:
        set_blacklist(file=path_to_blacklist, line=file.replace('_entities.json',''))
        continue
    
    # if authors is empty we will find in metadata.csv file
    if len(list_of_authors)==0:
        ##if string is NaN
        try:
            if article_id.startswith('PMC'):
                try:
                    authors = get_authors_metadata(data=metadata, label=pmcid, ident= article_id)
                    list_of_authors.append(authors) 
                except Exception as e:
                    print(f'Get authors name in pubmed. Error: {e}')    
                    pmid = get_pmid(pmcid=article_id)
                    authors = get_authors_by_bio(pmid)
                    for a in authors:                
                        first = unidecode.unidecode(a['first'])
                        last = unidecode.unidecode(a['last']) 
                    list_of_authors.append(first + ', '+  last)                     
            else:
                authors = get_authors_metadata(data=metadata, label=sha, ident= article_id)
                list_of_authors.append(authors) 
        except Exception as e:
            print(f'Empty values {e}')   
            set_blacklist(file=path_to_blacklist, line=file.replace('_entities.json',''))                
        continue
    count+=1
    # if count > 0:
    #     break

###  ---- End of Metadata ----            
    
    user_item_rating = get_user_item_rating(lst=list_of_authors, df=df_entities)
    #print(user_item_rating)
    
    ## add publish_date in array in index column = 3
    user_item_rating = np.insert(user_item_rating, 3, publish_date, axis=1)
    # print(user_item_rating)
    user_item_rating_all.append(user_item_rating)
# Out:
# 0 - 6
# PMC6275129_entities.json
#                                        entities  count   entities_id
# 0    http://purl.obolibrary.org/obo/CHEBI_33731   1181   CHEBI_33731
# 1    http://purl.obolibrary.org/obo/CHEBI_35640    663   CHEBI_35640
# 2    http://purl.obolibrary.org/obo/CHEBI_34935    138   CHEBI_34935
# 3    http://purl.obolibrary.org/obo/CHEBI_84123    115   CHEBI_84123
# 4      http://purl.obolibrary.org/obo/DOID_2841    115     DOID_2841
# 5         http://purl.obolibrary.org/obo/DOID_4     92        DOID_4
# 6    http://purl.obolibrary.org/obo/CHEBI_33281     46   CHEBI_33281
# 7    http://purl.obolibrary.org/obo/CHEBI_18111     46   CHEBI_18111
# 8    http://purl.obolibrary.org/obo/CHEBI_25016     46   CHEBI_25016
# 9    http://purl.obolibrary.org/obo/CHEBI_33341     46   CHEBI_33341
# 10     http://purl.obolibrary.org/obo/DOID_4483     46     DOID_4483
# 11   http://purl.obolibrary.org/obo/CHEBI_28515     28   CHEBI_28515
# 12   http://purl.obolibrary.org/obo/CHEBI_16044     23   CHEBI_16044
# 13   http://purl.obolibrary.org/obo/CHEBI_33697     23   CHEBI_33697
# 14   http://purl.obolibrary.org/obo/CHEBI_24433     23   CHEBI_24433
# 15  http://purl.obolibrary.org/obo/DOID_0080815     23  DOID_0080815
# 16   http://purl.obolibrary.org/obo/CHEBI_36976     23   CHEBI_36976
# 17      http://purl.obolibrary.org/obo/DOID_850     23      DOID_850
# 18   http://purl.obolibrary.org/obo/CHEBI_50906     23   CHEBI_50906
# 19    http://purl.obolibrary.org/obo/DOID_10754     23    DOID_10754
# 20     http://purl.obolibrary.org/obo/DOID_2275     23     DOID_2275
# 21     http://purl.obolibrary.org/obo/DOID_1485     23     DOID_1485
# 22     http://purl.obolibrary.org/obo/DOID_3083     23     DOID_3083
# 23      http://purl.obolibrary.org/obo/DOID_934     23      DOID_934
# 24     http://purl.obolibrary.org/obo/DOID_2723     23     DOID_2723
# 25     http://purl.obolibrary.org/obo/DOID_4481     23     DOID_4481
# 26     http://purl.obolibrary.org/obo/DOID_9415     23     DOID_9415
# 27   http://purl.obolibrary.org/obo/CHEBI_30216      7   CHEBI_30216
# 2018
# 1 - 6
# 06ced00a5fc04215949aa72528f2eeaae1d58927_entities.json
#                                        entities  count   entities_id
# 0    http://purl.obolibrary.org/obo/CHEBI_52214   1298   CHEBI_52214
# 1    http://purl.obolibrary.org/obo/CHEBI_16412   1218   CHEBI_16412
# 2    http://purl.obolibrary.org/obo/CHEBI_35195    660   CHEBI_35195
# 3    http://purl.obolibrary.org/obo/CHEBI_16646    580   CHEBI_16646
# 4    http://purl.obolibrary.org/obo/CHEBI_25367    576   CHEBI_25367
# 5     http://purl.obolibrary.org/obo/CHEBI_3815    527    CHEBI_3815
# 6    http://purl.obolibrary.org/obo/CHEBI_50699    454   CHEBI_50699
# 7    http://purl.obolibrary.org/obo/CHEBI_36080    418   CHEBI_36080
# 8    http://purl.obolibrary.org/obo/CHEBI_17234    305   CHEBI_17234
# 9    http://purl.obolibrary.org/obo/CHEBI_18059    286   CHEBI_18059
# 10   http://purl.obolibrary.org/obo/CHEBI_33563    283   CHEBI_33563
# 11   http://purl.obolibrary.org/obo/CHEBI_59132    272   CHEBI_59132
# 12   http://purl.obolibrary.org/obo/CHEBI_15356    270   CHEBI_15356
# 13   http://purl.obolibrary.org/obo/CHEBI_63248    258   CHEBI_63248
# 14   http://purl.obolibrary.org/obo/CHEBI_18154    257   CHEBI_18154
# 15   http://purl.obolibrary.org/obo/CHEBI_37684    257   CHEBI_37684
# 16   http://purl.obolibrary.org/obo/CHEBI_48343    244   CHEBI_48343
# 17   http://purl.obolibrary.org/obo/CHEBI_25016    244   CHEBI_25016
# 18   http://purl.obolibrary.org/obo/CHEBI_22984    244   CHEBI_22984
# 19   http://purl.obolibrary.org/obo/CHEBI_33250    244   CHEBI_33250
# 60      http://purl.obolibrary.org/obo/DOID_299     61      DOID_299
# 61   http://purl.obolibrary.org/obo/CHEBI_33905     61   CHEBI_33905
# 62   http://purl.obolibrary.org/obo/CHEBI_35224     61   CHEBI_35224
# 63   http://purl.obolibrary.org/obo/CHEBI_33699     61   CHEBI_33699
# 64   http://purl.obolibrary.org/obo/CHEBI_35222     61   CHEBI_35222
# 65   http://purl.obolibrary.org/obo/CHEBI_26274     61   CHEBI_26274
# 66   http://purl.obolibrary.org/obo/CHEBI_17306     61   CHEBI_17306
# 67   http://purl.obolibrary.org/obo/CHEBI_33284     61   CHEBI_33284
# 68   http://purl.obolibrary.org/obo/CHEBI_29256     61   CHEBI_29256
# 69   http://purl.obolibrary.org/obo/CHEBI_72813     61   CHEBI_72813
# 70   http://purl.obolibrary.org/obo/CHEBI_50904     61   CHEBI_50904
# 71   http://purl.obolibrary.org/obo/CHEBI_26667     61   CHEBI_26667
# 72   http://purl.obolibrary.org/obo/CHEBI_64198     61   CHEBI_64198
# 73   http://purl.obolibrary.org/obo/CHEBI_22907     61   CHEBI_22907
# 74     http://purl.obolibrary.org/obo/DOID_2841     61     DOID_2841
# 75     http://purl.obolibrary.org/obo/DOID_1205     61     DOID_1205
# 76   http://purl.obolibrary.org/obo/CHEBI_16247     39   CHEBI_16247
# 77    http://purl.obolibrary.org/obo/CHEBI_5717     26    CHEBI_5717
# 78   http://purl.obolibrary.org/obo/CHEBI_33704     26   CHEBI_33704
# 79   http://purl.obolibrary.org/obo/CHEBI_16991     13   CHEBI_16991
# 80  http://purl.obolibrary.org/obo/CHEBI_147370     13  CHEBI_147370
# 81   http://purl.obolibrary.org/obo/CHEBI_32359     13   CHEBI_32359
# 82  http://purl.obolibrary.org/obo/CHEBI_165825     13  CHEBI_165825
# 83   http://purl.obolibrary.org/obo/CHEBI_23888     13   CHEBI_23888
# 84   http://purl.obolibrary.org/obo/CHEBI_52290     13   CHEBI_52290
# 85   http://purl.obolibrary.org/obo/CHEBI_35381     13   CHEBI_35381
# 86   http://purl.obolibrary.org/obo/CHEBI_18276     13   CHEBI_18276
# 87   http://purl.obolibrary.org/obo/CHEBI_16240     13   CHEBI_16240
# 88   http://purl.obolibrary.org/obo/CHEBI_44785     13   CHEBI_44785
# 89   http://purl.obolibrary.org/obo/CHEBI_16178     13   CHEBI_16178
# 90   http://purl.obolibrary.org/obo/CHEBI_34699     13   CHEBI_34699
# 91      http://purl.obolibrary.org/obo/DOID_399     13      DOID_399
# 92   http://purl.obolibrary.org/obo/CHEBI_59524     13   CHEBI_59524
# 25 Aug 2000
# 2 - 6
# .ipynb_checkpoints
# Json file does not contain values. Error message [Errno 21] Is a directory: '../data/comm_use_subset_entities/.ipynb_checkpoints'
# 2 - 6
# PMC446188_entities.json
#                                        entities  count   entities_id
# 0    http://purl.obolibrary.org/obo/CHEBI_36976    556   CHEBI_36976
# 1      http://purl.obolibrary.org/obo/DOID_2945    195     DOID_2945
# 2    http://purl.obolibrary.org/obo/CHEBI_33697    168   CHEBI_33697
# 3    http://purl.obolibrary.org/obo/CHEBI_46882     63   CHEBI_46882
# 4    http://purl.obolibrary.org/obo/CHEBI_33704     63   CHEBI_33704
# 5    http://purl.obolibrary.org/obo/CHEBI_37527     63   CHEBI_37527
# 6    http://purl.obolibrary.org/obo/CHEBI_17089     63   CHEBI_17089
# 7      http://purl.obolibrary.org/obo/DOID_8469     63     DOID_8469
# 8    http://purl.obolibrary.org/obo/CHEBI_84123     42   CHEBI_84123
# 9    http://purl.obolibrary.org/obo/CHEBI_36080     42   CHEBI_36080
# 10  http://purl.obolibrary.org/obo/DOID_0080327     42  DOID_0080327
# 11     http://purl.obolibrary.org/obo/DOID_6132     42     DOID_6132
# 12      http://purl.obolibrary.org/obo/DOID_225     21      DOID_225
# 13   http://purl.obolibrary.org/obo/CHEBI_29852     21   CHEBI_29852
# 14   http://purl.obolibrary.org/obo/CHEBI_59132     21   CHEBI_59132
# 15     http://purl.obolibrary.org/obo/DOID_2237     21     DOID_2237
# 16     http://purl.obolibrary.org/obo/DOID_2326     21     DOID_2326
# 17   http://purl.obolibrary.org/obo/CHEBI_40799     21   CHEBI_40799
# 2004
# 3 - 6
# cdb29ec7a9029d22f6fbf7ee04543819591acdc2_entities.json
#                                       entities  count   entities_id
# 0     http://purl.obolibrary.org/obo/DOID_2945     10     DOID_2945
# 1  http://purl.obolibrary.org/obo/DOID_0080327      8  DOID_0080327
# 2   http://purl.obolibrary.org/obo/CHEBI_36976      7   CHEBI_36976
# 3   http://purl.obolibrary.org/obo/CHEBI_48341      3   CHEBI_48341
# 2004
# Empty values name 'sha' is not defined

# %%
flat_list = []
for sublist in user_item_rating_all:
    for item in sublist:
        flat_list.append(item)

# %%
array = np.array(flat_list)

final_data = pd.DataFrame(array,  columns=['user', 'item', 'rating', 'year'])

sum_df = final_data.groupby(['user', 'item', 'year']).size().reset_index().rename(columns={0: 'rating'})
    
df_with_user_id = id_to_index(sum_df)

# %%
# swap columns: user and index_user, and after rename to author_name
#df_with_user_id['index_user'], df_with_user_id['user'] = df_with_user_id['user'], df_with_user_id['index_user']
df_with_user_id.rename(columns={'user': 'author_name', 'index_user': 'user'}, inplace = True)

# %% [markdown]
# ### get entities labels

# %%
list_of_entities = df_with_user_id.item.unique()
print(list_of_entities)
# Out:
# ['CHEBI_16044' 'CHEBI_18111' 'CHEBI_24433' 'CHEBI_25016' 'CHEBI_28515'
#  'CHEBI_30216' 'CHEBI_33281' 'CHEBI_33341' 'CHEBI_33697' 'CHEBI_33731'
#  'CHEBI_34935' 'CHEBI_35640' 'CHEBI_36976' 'CHEBI_50906' 'CHEBI_84123'
#  'DOID_0080815' 'DOID_10754' 'DOID_1485' 'DOID_2275' 'DOID_2723'
#  'DOID_2841' 'DOID_3083' 'DOID_4' 'DOID_4481' 'DOID_4483' 'DOID_850'
#  'DOID_934' 'DOID_9415' 'CHEBI_17089' 'CHEBI_29852' 'CHEBI_33704'
#  'CHEBI_36080' 'CHEBI_37527' 'CHEBI_40799' 'CHEBI_46882' 'CHEBI_59132'
#  'DOID_0080327' 'DOID_2237' 'DOID_225' 'DOID_2326' 'DOID_2945' 'DOID_6132'
#  'DOID_8469' 'CHEBI_132554' 'CHEBI_145810' 'CHEBI_147370' 'CHEBI_15356'
#  'CHEBI_16178' 'CHEBI_16240' 'CHEBI_16247' 'CHEBI_16412' 'CHEBI_16480'
#  'CHEBI_165825' 'CHEBI_16646' 'CHEBI_16670' 'CHEBI_16749' 'CHEBI_16991'
#  'CHEBI_17234' 'CHEBI_17268' 'CHEBI_17306' 'CHEBI_17895' 'CHEBI_18059'
#  'CHEBI_18095' 'CHEBI_18154' 'CHEBI_18276' 'CHEBI_18368' 'CHEBI_22907'
#  'CHEBI_22984' 'CHEBI_23888' 'CHEBI_24261' 'CHEBI_24400' 'CHEBI_24870'
#  'CHEBI_25367' 'CHEBI_25741' 'CHEBI_26274' 'CHEBI_26667' 'CHEBI_27780'
#  'CHEBI_28808' 'CHEBI_29256' 'CHEBI_29342' 'CHEBI_32359' 'CHEBI_32835'
#  'CHEBI_33250' 'CHEBI_33284' 'CHEBI_33563' 'CHEBI_33699' 'CHEBI_3379'
#  'CHEBI_33905' 'CHEBI_34699' 'CHEBI_35195' 'CHEBI_35222' 'CHEBI_35224'
#  'CHEBI_35381' 'CHEBI_37684' 'CHEBI_3815' 'CHEBI_39124' 'CHEBI_41879'
#  'CHEBI_42191' 'CHEBI_44785' 'CHEBI_48343' 'CHEBI_48377' 'CHEBI_50699'
#  'CHEBI_50904' 'CHEBI_52214' 'CHEBI_52290' 'CHEBI_5717' 'CHEBI_59485'
#  'CHEBI_59524' 'CHEBI_60175' 'CHEBI_63248' 'CHEBI_64198' 'CHEBI_72813'
#  'CHEBI_89981' 'CHEBI_9584' 'DOID_0111962' 'DOID_10325' 'DOID_1205'
#  'DOID_299' 'DOID_3910' 'DOID_399' 'DOID_627']

# %% [markdown]
# ### loading ontologies

# %%
chebi, do, go, hp = loading_items(is_chebi, is_do, is_go, is_hp)
# Out:
# Downloading ... chebi.owl
# i am here
# Downloading ... doid.owl
# Loading ... chebi
# Loading ... doid

# %%
# entities_label = get_entities_labels(list_of_entities, chebi, hp, go, do)
entities_label = get_entities_labels(lst=list_of_entities, prefix_chebi=chebi, prefix_do=do, prefix_go=go, prefix_hp=hp)
print(entities_label)
# Out:
# [rdflib.term.Literal('L-methionine residue', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('ribosomal RNA', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('group', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('lead atom', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('acetoacetamide', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('alpha-particle', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('antimicrobial agent', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('titanium atom', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('ribonucleic acid', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('cluster', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('propyzamide', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('adrenergic uptake inhibitor', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('nucleotide', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('role', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('advanced glycation end-product', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('childhood-onset asthma', lang='en'), rdflib.term.Literal('otitis media', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('cystic fibrosis', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('pharyngitis', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('dermatitis', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('asthma', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('chronic obstructive pulmonary disease', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('disease', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('allergic rhinitis', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('rhinitis', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('lung disease', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('viral infectious disease', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('allergic asthma', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('glycoprotein', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('methylarsonic acid', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('alpha-amino acid', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('protein', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('acid', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('androsta-1,4-diene-3,17-dione', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('primary amino group', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('antigen', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.Literal('multinucleated neurons, anh ...

# %%
df_entities = pd.DataFrame(list_of_entities, columns=["item_id"])
df_entities["entity_name"] = np.array(entities_label)
print(df_entities)
# Out:
#           item_id                                        entity_name
# 0     CHEBI_16044                               L-methionine residue
# 1     CHEBI_18111                                      ribosomal RNA
# 2     CHEBI_24433                                              group
# 3     CHEBI_25016                                          lead atom
# 4     CHEBI_28515                                     acetoacetamide
# 5     CHEBI_30216                                     alpha-particle
# 6     CHEBI_33281                                antimicrobial agent
# 7     CHEBI_33341                                      titanium atom
# 8     CHEBI_33697                                   ribonucleic acid
# 9     CHEBI_33731                                            cluster
# 10    CHEBI_34935                                        propyzamide
# 11    CHEBI_35640                        adrenergic uptake inhibitor
# 12    CHEBI_36976                                         nucleotide
# 13    CHEBI_50906                                               role
# 14    CHEBI_84123                     advanced glycation end-product
# 15   DOID_0080815                             childhood-onset asthma
# 16     DOID_10754                                       otitis media
# 17      DOID_1485                                    cystic fibrosis
# 18      DOID_2275                                        pharyngitis
# 19      DOID_2723                                         dermatitis
# 20      DOID_2841                                             asthma
# 21      DOID_3083              chronic obstructive pulmonary disease
# 22         DOID_4                                            disease
# 23      DOID_4481                                  allergic rhinitis
# 24      DOID_4483                                           rhinitis
# 25       DOID_850                                       lung disease
# 26       DOID_934                           viral infectious disease
# 27      DOID_9415                                    allergic asthma
# 28    CHEBI_17089                                       glycoprotein
# 29    CHEBI_29852                                 methylarsonic acid
# 30    CHEBI_33704                                   alpha-amino acid
# 31    CHEBI_36080                                            protein
# 32    CHEBI_37527                                               acid
# 33    CHEBI_40799                      androsta-1,4-diene-3,17-dione
# 34    CHEBI_46882                                primary amino group
# 35    CHEBI_59132                                            antigen
# 36   DOID_0080327  multinucleated neurons, anhydramnios, renal dy...
# 37      DOID_2237                                          hepatitis
# 38       DOID_225                                           syndrome
# 39      DOID_2326                                    gastroenteritis
# 40      DOID_2945                  severe acute respiratory syndrome
# 41      DOID_6132                                         bronchitis
# 42      DOID_8469                                          influenza
# 43   CHEBI_132554                                           oligomer
# 44   CHEBI_145810                                            insulin
# 45   CHEBI_147370                                 imazaquin-ammonium
# 46    CHEBI_15356                                           cysteine
# 47    CHEBI_16178                                      phosphomannan
# 48    CHEBI_16240                                  hydrogen peroxide
# 49    CHEBI_16247                                       phospholipid
# 50    CHEBI_16412                                 lipopolysaccharide
# 51    CHEBI_16480                                       nitric oxide
# 52   CHEBI_165825                                                GpA
# 53    CHEBI_16646                                       carbohydrate
# 54    CHEBI_16670                                            peptide
# 55    CHEBI_16749                     1-phosphatidyl-1D-myo-inositol
# 56    CHEBI_16991                              deoxyribonucleic acid
# 57    CHEBI_17234                                            glucose
# 58    CHEBI_17268                                       myo-inositol
# 59    CHEBI_17306                                            maltose
# 60    CHEBI_17895                                         L-tyrosine
# 61    CHEBI_18059                                              lipid
# 62    CHEBI_18095                          trans-4-hydroxy-L-proline
# 63    CHEBI_18154                                     polysaccharide
# 64    CHEBI_18276                                         dihydrogen
# 65    CHEBI_18368                       D-glucosyl-N-acylsphingosine
# 66    CHEBI_22907                                          bleomycin
# 67    CHEBI_22984                                       calcium atom
# 68    CHEBI_23888                                               drug
# 69    CHEBI_24261                                     glucocorticoid
# 70    CHEBI_24400                                          glycoside
# 71    CHEBI_24870                                                ion
# 72    CHEBI_25367                                           molecule
# 73    CHEBI_25741                                              oxide
# 74    CHEBI_26274                                       prolyl group
# 75    CHEBI_26667                                        sialic acid
# 76    CHEBI_27780                                          detergent
# 77    CHEBI_28808                                             mannan
# 78    CHEBI_29256                                              thiol
# 79    CHEBI_29342                                        imino group
# 80    CHEBI_32359                                   dodecanoyl group
# 81    CHEBI_32835                                  threonine residue
# 82    CHEBI_33250                                               atom
# 83    CHEBI_33284                                           nutrient
# 84    CHEBI_33563                                         glycolipid
# 85    CHEBI_33699                                      messenger RNA
# 86     CHEBI_3379                            capsular polysaccharide
# 87    CHEBI_33905                                            heptose
# 88    CHEBI_34699                                    diethyl sulfate
# 89    CHEBI_35195                                         surfactant
# 90    CHEBI_35222                                          inhibitor
# 91    CHEBI_35224                                           effector
# 92    CHEBI_35381                                     monosaccharide
# 93    CHEBI_37684                                            mannose
# 94     CHEBI_3815                                           Collagen
# 95    CHEBI_39124                                        calcium ion
# 96    CHEBI_41879                                      dexamethasone
# 97    CHEBI_42191                    ethylenediaminetetraacetic acid
# 98    CHEBI_44785                                           peroxide
# 99    CHEBI_48343                                          disulfide
# 100   CHEBI_48377                                        imidic acid
# 101   CHEBI_50699                                    oligosaccharide
# 102   CHEBI_50904                                           allergen
# 103   CHEBI_52214                                             ligand
# 104   CHEBI_52290                                            mitogen
# 105    CHEBI_5717                       high-mannose oligosaccharide
# 106   CHEBI_59485  L-alpha-D-Hepp-(1->2)-L-alpha-D-Hepp-(1->3)-[b...
# 107   CHEBI_59524                                  lipoarabinomannan
# 108   CHEBI_60175                                    5-hydroxylysine
# 109   CHEBI_63248                                    oxidising agent
# 110   CHEBI_64198                                        dimercaprol
# 111   CHEBI_72813                                  exopolysaccharide
# 112   CHEBI_89981                                 LPS with O-antigen
# 113    CHEBI_9584                         desiccated thyroid extract
# 114  DOID_0111962                          combined immunodeficiency
# 115    DOID_10325                                          silicosis
# 116     DOID_1205                                   allergic disease
# 117      DOID_299                                     adenocarcinoma
# 118     DOID_3910                                lung adenocarcinoma
# 119      DOID_399                                       tuberculosis
# 120      DOID_627                   severe combined immunodeficiency

# %%
print('mapping labels')
df_with_user_id["item_name"] = df_with_user_id["item"].map(df_entities.set_index('item_id')["entity_name"]).fillna(0)
# Out:
# mapping labels

# %%
print(df_with_user_id)
# Out:
#            author_name          item         year  rating  user  \
# 0          Binbin,  Xu   CHEBI_16044         2018       1     0
# 1          Binbin,  Xu   CHEBI_18111         2018       1     0
# 2          Binbin,  Xu   CHEBI_24433         2018       1     0
# 3          Binbin,  Xu   CHEBI_25016         2018       1     0
# 4          Binbin,  Xu   CHEBI_28515         2018       1     0
# 5          Binbin,  Xu   CHEBI_30216         2018       1     0
# 6          Binbin,  Xu   CHEBI_33281         2018       1     0
# 7          Binbin,  Xu   CHEBI_33341         2018       1     0
# 8          Binbin,  Xu   CHEBI_33697         2018       1     0
# 9          Binbin,  Xu   CHEBI_33731         2018       1     0
# 10         Binbin,  Xu   CHEBI_34935         2018       1     0
# 11         Binbin,  Xu   CHEBI_35640         2018       1     0
# 12         Binbin,  Xu   CHEBI_36976         2018       1     0
# 13         Binbin,  Xu   CHEBI_50906         2018       1     0
# 14         Binbin,  Xu   CHEBI_84123         2018       1     0
# 15         Binbin,  Xu  DOID_0080815         2018       1     0
# 16         Binbin,  Xu    DOID_10754         2018       1     0
# 17         Binbin,  Xu     DOID_1485         2018       1     0
# 18         Binbin,  Xu     DOID_2275         2018       1     0
# 19         Binbin,  Xu     DOID_2723         2018       1     0
# 20         Binbin,  Xu     DOID_2841         2018       1     0
# 21         Binbin,  Xu     DOID_3083         2018       1     0
# 22         Binbin,  Xu        DOID_4         2018       1     0
# 23         Binbin,  Xu     DOID_4481         2018       1     0
# 24         Binbin,  Xu     DOID_4483         2018       1     0
# 25         Binbin,  Xu      DOID_850         2018       1     0
# 26         Binbin,  Xu      DOID_934         2018       1     0
# 27         Binbin,  Xu     DOID_9415         2018       1     0
# 28   Eric,  Boerwinkle   CHEBI_17089         2004       1     1
# 29   Eric,  Boerwinkle   CHEBI_29852         2004       1     1
# 30   Eric,  Boerwinkle   CHEBI_33697         2004       1     1
# 31   Eric,  Boerwinkle   CHEBI_33704         2004       1     1
# 32   Eric,  Boerwinkle   CHEBI_36080         2004       1     1
# 33   Eric,  Boerwinkle   CHEBI_36976         2004       1     1
# 34   Eric,  Boerwinkle   CHEBI_37527         2004       1     1
# 35   Eric,  Boerwinkle   CHEBI_40799         2004       1     1
# 36   Eric,  Boerwinkle   CHEBI_46882         2004       1     1
# 37   Eric,  Boerwinkle   CHEBI_59132         2004       1     1
# 38   Eric,  Boerwinkle   CHEBI_84123         2004       1     1
# 39   Eric,  Boerwinkle  DOID_0080327         2004       1     1
# 40   Eric,  Boerwinkle     DOID_2237         2004       1     1
# 41   Eric,  Boerwinkle      DOID_225         2004       1     1
# 42   Eric,  Boerwinkle     DOID_2326         2004       1     1
# 43   Eric,  Boerwinkle     DOID_2945         2004       1     1
# 44   Eric,  Boerwinkle     DOID_6132         2004       1     1
# 45   Eric,  Boerwinkle     DOID_8469         2004       1     1
# 46     Erika, C Crouch  CHEBI_132554  25 Aug 2000       1     2
# 47     Erika, C Crouch  CHEBI_145810  25 Aug 2000       1     2
# 48     Erika, C Crouch  CHEBI_147370  25 Aug 2000       1     2
# 49     Erika, C Crouch   CHEBI_15356  25 Aug 2000       1     2
# 50     Erika, C Crouch   CHEBI_16178  25 Aug 2000       1     2
# 51     Erika, C Crouch   CHEBI_16240  25 Aug 2000       1     2
# 52     Erika, C Crouch   CHEBI_16247  25 Aug 2000       1     2
# 53     Erika, C Crouch   CHEBI_16412  25 Aug 2000       1     2
# 54     Erika, C Crouch   CHEBI_16480  25 Aug 2000       1     2
# 142       Haipeng,  Li   CHEBI_33704         2004       1     3
# 143       Haipeng,  Li   CHEBI_36080         2004       1     3
# 144       Haipeng,  Li   CHEBI_36976         2004       1     3
# 145       Haipeng,  Li   CHEBI_37527         2004       1     3
# 146       Haipeng,  Li   CHEBI_40799         2004       1     3
# 147       Haipeng,  Li   CHEBI_46882         2004       1     3
# 148       Haipeng,  Li   CHEBI_59132         2004       1     3
# 149       Haipeng,  Li   CHEBI_84123         2004       1     3
# 150       Haipeng,  Li  DOID_0080327         2004       1     3
# 151       Haipeng,  Li     DOID_2237         2004       1     3
# 152       Haipeng,  Li      DOID_225         2004       1     3
# 153       Haipeng,  Li     DOID_2326         2004       1     3
# 154       Haipeng,  Li     DOID_2945         2004       1     3
# 155       Haipeng,  Li     DOID_6132         2004       1     3
# 156       Haipeng,  Li     DOID_8469         2004       1     3
# 157      Insa,  Korten   CHEBI_16044         2018       1     4
# 158      Insa,  Korten   CHEBI_18111         2018       1     4
# 159      Insa,  Korten   CHEBI_24433         2018       1     4
# 160      Insa,  Korten   CHEBI_25016         2018       1     4
# 161      Insa,  Korten   CHEBI_28515         2018       1     4
# 162      Insa,  Korten   CHEBI_30216         2018       1     4
# 163      Insa,  Korten   CHEBI_33281         2018       1     4
# 164      Insa,  Korten   CHEBI_33341         2018       1     4
# 165      Insa,  Korten   CHEBI_33697         2018       1     4
# 166      Insa,  Korten   CHEBI_33731         2018       1     4
# 167      Insa,  Korten   CHEBI_34935         2018       1     4
# 168      Insa,  Korten   CHEBI_35640         2018       1     4
# 169      Insa,  Korten   CHEBI_36976         2018       1     4
# 170      Insa,  Korten   CHEBI_50906         2018       1     4
# 171      Insa,  Korten   CHEBI_84123         2018       1     4
# 172      Insa,  Korten  DOID_0080815         2018       1     4
# 173      Insa,  Korten    DOID_10754         2018       1     4
# 174      Insa,  Korten     DOID_1485         2018       1     4
# 175      Insa,  Korten     DOID_2275         2018       1     4
# 176      Insa,  Korten     DOID_2723         2018       1     4
# 177      Insa,  Korten     DOID_2841         2018       1     4
# 178      Insa,  Korten     DOID_3083         2018       1     4
# 179      Insa,  Korten        DOID_4         2018       1     4
# 180      Insa,  Korten     DOID_4481         2018       1     4
# 181      Insa,  Korten     DOID_4483         2018       1     4
# 182      Insa,  Korten      DOID_850         2018       1     4
# 183      Insa,  Korten      DOID_934         2018       1     4
# 184      Insa,  Korten     DOID_9415         2018       1     4
# 185    Jakob,  Usemann   CHEBI_16044         2018       1     5
# 186    Jakob,  Usemann   CHEBI_18111         2018       1     5
# 187    Jakob,  Usemann   CHEBI_24433         2018       1     5
# 188    Jakob,  Usemann   CHEBI_25016         2018       1     5
# 189    Jakob,  Usemann   CHEBI_28515         2018       1     5
# 190    Jakob,  Usemann   CHEBI_30216         2018       1     5
# 191    Jakob,  Usemann   CHEBI_33281         2018       1     5
# 192    Jakob,  Usemann   CHEBI_33341         2018       1     5
# 193    Jakob,  Usemann   CHEBI_33697         2018       1     5
# 194    Jakob,  Usemann   CHEBI_33731         2018       1     5
# 458        YunXin,  Fu   CHEBI_36976         2004       1    16
# 459        YunXin,  Fu   CHEBI_37527         2004       1    16
# 460        YunXin,  Fu   CHEBI_40799         2004       1    16
# 461        YunXin,  Fu   CHEBI_46882         2004       1    16
# 462        YunXin,  Fu   CHEBI_59132         2004       1    16
# 463        YunXin,  Fu   CHEBI_84123         2004       1    16
# 464        YunXin,  Fu  DOID_0080327         2004       1    16
# 465        YunXin,  Fu     DOID_2237         2004       1    16
# 466        YunXin,  Fu      DOID_225         2004       1    16
# 467        YunXin,  Fu     DOID_2326         2004       1    16
# 468        YunXin,  Fu     DOID_2945         2004       1    16
# 469        YunXin,  Fu     DOID_6132         2004       1    16
# 470        YunXin,  Fu     DOID_8469         2004       1    16
# 471   Zhongming,  Zhao   CHEBI_17089         2004       1    17
# 472   Zhongming,  Zhao   CHEBI_29852         2004       1    17
# 473   Zhongming,  Zhao   CHEBI_33697         2004       1    17
# 474   Zhongming,  Zhao   CHEBI_33704         2004       1    17
# 475   Zhongming,  Zhao   CHEBI_36080         2004       1    17
# 476   Zhongming,  Zhao   CHEBI_36976         2004       1    17
# 477   Zhongming,  Zhao   CHEBI_37527         2004       1    17
# 478   Zhongming,  Zhao   CHEBI_40799         2004       1    17
# 479   Zhongming,  Zhao   CHEBI_46882         2004       1    17
# 480   Zhongming,  Zhao   CHEBI_59132         2004       1    17
# 481   Zhongming,  Zhao   CHEBI_84123         2004       1    17
# 482   Zhongming,  Zhao  DOID_0080327         2004       1    17
# 483   Zhongming,  Zhao     DOID_2237         2004       1    17
# 484   Zhongming,  Zhao      DOID_225         2004       1    17
# 485   Zhongming,  Zhao     DOID_2326         2004       1    17
# 486   Zhongming,  Zhao     DOID_2945         2004       1    17
# 487   Zhongming,  Zhao     DOID_6132         2004       1    17
# 488   Zhongming,  Zhao     DOID_8469         2004       1    17
#
#                                              item_name
# 0                                 L-methionine residue
# 1                                        ribosomal RNA
# 2                                                group
# 3                                            lead atom
# 4                                       acetoacetamide
# 5                                       alpha-particle
# 6                                  antimicrobial agent
# 7                                        titanium atom
# 8                                     ribonucleic acid
# 9                                              cluster
# 10                                         propyzamide
# 11                         adrenergic uptake inhibitor
# 12                                          nucleotide
# 13                                                role
# 14                      advanced glycation end-product
# 15                              childhood-onset asthma
# 16                                        otitis media
# 17                                     cystic fibrosis
# 18                                         pharyngitis
# 19                                          dermatitis
# 20                                              asthma
# 21               chronic obstructive pulmonary disease
# 22                                             disease
# 23                                   allergic rhinitis
# 24                                            rhinitis
# 25                                        lung disease
# 26                            viral infectious disease
# 27                                     allergic asthma
# 28                                        glycoprotein
# 29                                  methylarsonic acid
# 30                                    ribonucleic acid
# 31                                    alpha-amino acid
# 32                                             protein
# 33                                          nucleotide
# 34                                                acid
# 35                       androsta-1,4-diene-3,17-dione
# 36                                 primary amino group
# 37                                             antigen
# 38                      advanced glycation end-product
# 39   multinucleated neurons, anhydramnios, renal dy...
# 40                                           hepatitis
# 41                                            syndrome
# 42                                     gastroenteritis
# 43                   severe acute respiratory syndrome
# 44                                          bronchitis
# 45                                           influenza
# 46                                            oligomer
# 47                                             insulin
# 48                                  imazaquin-ammonium
# 49                                            cysteine
# 50                                       phosphomannan
# 51                                   hydrogen peroxide
# 52                                        phospholipid
# 53                                  lipopolysaccharide
# 54                                        nitric oxide
# 55                                                 GpA
# 56                                        carbohydrate
# 57                                             peptide
# 58                      1-phosphatidyl-1D-myo-inositol
# 59                               deoxyribonucleic acid
# 60                                        glycoprotein
# 61                                             glucose
# 62                                        myo-inositol
# 63                                             maltose
# 64                                          L-tyrosine
# 65                                               lipid
# 66                           trans-4-hydroxy-L-proline
# 67                                      polysaccharide
# 68                                          dihydrogen
# 69                        D-glucosyl-N-acylsphingosine
# 70                                           bleomycin
# 71                                        calcium atom
# 72                                                drug
# 73                                      glucocorticoid
# 74                                           glycoside
# 75                                               group
# 76                                                 ion
# 77                                           lead atom
# 78                                            molecule
# 79                                               oxide
# 80                                        prolyl group
# 81                                         sialic acid
# 82                                           detergent
# 83                                              mannan
# 84                                               thiol
# 85                                         imino group
# 86                                    dodecanoyl group
# 87                                   threonine residue
# 88                                                atom
# 89                                 antimicrobial agent
# 90                                            nutrient
# 91                                          glycolipid
# 92                                    ribonucleic acid
# 93                                       messenger RNA
# 94                                    alpha-amino acid
# 95                                             cluster
# 96                             capsular polysaccharide
# 97                                             heptose
# 98                                     diethyl sulfate
# 99                                          surfactant
# 100                                          inhibitor
# 101                                           effector
# 102                                     monosaccharide
# 103                                            protein
# 104                                               acid
# 105                                            mannose
# 106                                           Collagen
# 107                                        calcium ion
# 108                                      dexamethasone
# 109                    ethylenediaminetetraacetic acid
# 110                                           peroxide
# 111                                primary amino group
# 112                                          disulfide
# 113                                        imidic acid
# 114                                    oligosaccharide
# 115                                           allergen
# 116                                               role
# 117                                             ligand
# 118                                            mitogen
# 119                       high-mannose oligosaccharide
# 120                                            antigen
# 121  L-alpha-D-Hepp-(1->2)-L-alpha-D-Hepp-(1->3)-[b...
# 122                                  lipoarabinomannan
# 123                                    5-hydroxylysine
# 124                                    oxidising agent
# 125                                        dimercaprol
# 126                                  exopolysaccharide
# 127                                 LPS with O-antigen
# 128                         desiccated thyroid extract
# 129                          combined immunodeficiency
# 130                                          silicosis
# 131                                   allergic disease
# 132                                             asthma
# 133                                     adenocarcinoma
# 134                                lung adenocarcinoma
# 135                                       tuberculosis
# 136                                            disease
# 137                   severe combined immunodeficiency
# 138                                          influenza
# 139                                       glycoprotein
# 140                                 methylarsonic acid
# 141                                   ribonucleic acid
# 142                                   alpha-amino acid
# 143                                            protein
# 144                                         nucleotide
# 145                                               acid
# 146                      androsta-1,4-diene-3,17-dione
# 147                                primary amino group
# 148                                            antigen
# 149                     advanced glycation end-product
# 150  multinucleated neurons, anhydramnios, renal dy...
# 151                                          hepatitis
# 152                                           syndrome
# 153                                    gastroenteritis
# 154                  severe acute respiratory syndrome
# 155                                         bronchitis
# 156                                          influenza
# 157                               L-methionine residue
# 158                                      ribosomal RNA
# 159                                              group
# 160                                          lead atom
# 161                                     acetoacetamide
# 162                                     alpha-particle
# 163                                antimicrobial agent
# 164                                      titanium atom
# 165                                   ribonucleic acid
# 166                                            cluster
# 167                                        propyzamide
# 168                        adrenergic uptake inhibitor
# 169                                         nucleotide
# 170                                               role
# 171                     advanced glycation end-product
# 172                             childhood-onset asthma
# 173                                       otitis media
# 174                                    cystic fibrosis
# 175                                        pharyngitis
# 176                                         dermatitis
# 177                                             asthma
# 178              chronic obstructive pulmonary disease
# 179                                            disease
# 180                                  allergic rhinitis
# 181                                           rhinitis
# 182                                       lung disease
# 183                           viral infectious disease
# 184                                    allergic asthma
# 185                               L-methionine residue
# 186                                      ribosomal RNA
# 187                                              group
# 188                                          lead atom
# 189                                     acetoacetamide
# 190                                     alpha-particle
# 191                                antimicrobial agent
# 192                                      titanium atom
# 193                                   ribonucleic acid
# 194                                            cluster
# 195                                        propyzamide
# 196                        adrenergic uptake inhibitor
# 197                                         nucleotide
# 198                                               role
# 199                     advanced glycation end-product
# 200                             childhood-onset asthma
# 201                                       otitis media
# 202                                    cystic fibrosis
# 203                                        pharyngitis
# 204                                         dermatitis
# 205                                             asthma
# 206              chronic obstructive pulmonary disease
# 207                                            disease
# 208                                  allergic rhinitis
# 209                                           rhinitis
# 210                                       lung disease
# 211                           viral infectious disease
# 212                                    allergic asthma
# 213                                       glycoprotein
# 214                                 methylarsonic acid
# 215                                   ribonucleic acid
# 216                                   alpha-amino acid
# 217                                            protein
# 218                                         nucleotide
# 219                                               acid
# 220                      androsta-1,4-diene-3,17-dione
# 221                                primary amino group
# 222                                            antigen
# 223                     advanced glycation end-product
# 224  multinucleated neurons, anhydramnios, renal dy...
# 225                                          hepatitis
# 226                                           syndrome
# 227                                    gastroenteritis
# 228                  severe acute respiratory syndrome
# 229                                         bronchitis
# 230                                          influenza
# 231                               L-methionine residue
# 232                                      ribosomal RNA
# 233                                              group
# 234                                          lead atom
# 235                                     acetoacetamide
# 236                                     alpha-particle
# 237                                antimicrobial agent
# 238                                      titanium atom
# 239                                   ribonucleic acid
# 240                                            cluster
# 241                                        propyzamide
# 242                        adrenergic uptake inhibitor
# 243                                         nucleotide
# 244                                               role
# 245                     advanced glycation end-product
# 246                             childhood-onset asthma
# 247                                       otitis media
# 248                                    cystic fibrosis
# 249                                        pharyngitis
# 250                                         dermatitis
# 251                                             asthma
# 252              chronic obstructive pulmonary disease
# 253                                            disease
# 254                                  allergic rhinitis
# 255                                           rhinitis
# 256                                       lung disease
# 257                           viral infectious disease
# 258                                    allergic asthma
# 259                               L-methionine residue
# 260                                      ribosomal RNA
# 261                                              group
# 262                                          lead atom
# 263                                     acetoacetamide
# 264                                     alpha-particle
# 265                                antimicrobial agent
# 266                                      titanium atom
# 267                                   ribonucleic acid
# 268                                            cluster
# 269                                        propyzamide
# 270                        adrenergic uptake inhibitor
# 271                                         nucleotide
# 272                                               role
# 273                     advanced glycation end-product
# 274                             childhood-onset asthma
# 275                                       otitis media
# 276                                    cystic fibrosis
# 277                                        pharyngitis
# 278                                         dermatitis
# 279                                             asthma
# 280              chronic obstructive pulmonary disease
# 281                                            disease
# 282                                  allergic rhinitis
# 283                                           rhinitis
# 284                                       lung disease
# 285                           viral infectious disease
# 286                                    allergic asthma
# 287                               L-methionine residue
# 288                                      ribosomal RNA
# 289                                              group
# 290                                          lead atom
# 291                                     acetoacetamide
# 292                                     alpha-particle
# 293                                antimicrobial agent
# 294                                      titanium atom
# 295                                   ribonucleic acid
# 296                                            cluster
# 297                                        propyzamide
# 298                        adrenergic uptake inhibitor
# 299                                         nucleotide
# 300                                               role
# 301                     advanced glycation end-product
# 302                             childhood-onset asthma
# 303                                       otitis media
# 304                                    cystic fibrosis
# 305                                        pharyngitis
# 306                                         dermatitis
# 307                                             asthma
# 308              chronic obstructive pulmonary disease
# 309                                            disease
# 310                                  allergic rhinitis
# 311                                           rhinitis
# 312                                       lung disease
# 313                           viral infectious disease
# 314                                    allergic asthma
# 315                               L-methionine residue
# 316                                      ribosomal RNA
# 317                                              group
# 318                                          lead atom
# 319                                     acetoacetamide
# 320                                     alpha-particle
# 321                                antimicrobial agent
# 322                                      titanium atom
# 323                                   ribonucleic acid
# 324                                            cluster
# 325                                        propyzamide
# 326                        adrenergic uptake inhibitor
# 327                                         nucleotide
# 328                                               role
# 329                     advanced glycation end-product
# 330                             childhood-onset asthma
# 331                                       otitis media
# 332                                    cystic fibrosis
# 333                                        pharyngitis
# 334                                         dermatitis
# 335                                             asthma
# 336              chronic obstructive pulmonary disease
# 337                                            disease
# 338                                  allergic rhinitis
# 339                                           rhinitis
# 340                                       lung disease
# 341                           viral infectious disease
# 342                                    allergic asthma
# 343                               L-methionine residue
# 344                                      ribosomal RNA
# 345                                              group
# 346                                          lead atom
# 347                                     acetoacetamide
# 348                                     alpha-particle
# 349                                antimicrobial agent
# 350                                      titanium atom
# 351                                   ribonucleic acid
# 352                                            cluster
# 353                                        propyzamide
# 354                        adrenergic uptake inhibitor
# 355                                         nucleotide
# 356                                               role
# 357                     advanced glycation end-product
# 358                             childhood-onset asthma
# 359                                       otitis media
# 360                                    cystic fibrosis
# 361                                        pharyngitis
# 362                                         dermatitis
# 363                                             asthma
# 364              chronic obstructive pulmonary disease
# 365                                            disease
# 366                                  allergic rhinitis
# 367                                           rhinitis
# 368                                       lung disease
# 369                           viral infectious disease
# 370                                    allergic asthma
# 371                               L-methionine residue
# 372                                      ribosomal RNA
# 373                                              group
# 374                                          lead atom
# 375                                     acetoacetamide
# 376                                     alpha-particle
# 377                                antimicrobial agent
# 378                                      titanium atom
# 379                                   ribonucleic acid
# 380                                            cluster
# 381                                        propyzamide
# 382                        adrenergic uptake inhibitor
# 383                                         nucleotide
# 384                                               role
# 385                     advanced glycation end-product
# 386                             childhood-onset asthma
# 387                                       otitis media
# 388                                    cystic fibrosis
# 389                                        pharyngitis
# 390                                         dermatitis
# 391                                             asthma
# 392              chronic obstructive pulmonary disease
# 393                                            disease
# 394                                  allergic rhinitis
# 395                                           rhinitis
# 396                                       lung disease
# 397                           viral infectious disease
# 398                                    allergic asthma
# 399                                       glycoprotein
# 400                                 methylarsonic acid
# 401                                   ribonucleic acid
# 402                                   alpha-amino acid
# 403                                            protein
# 404                                         nucleotide
# 405                                               acid
# 406                      androsta-1,4-diene-3,17-dione
# 407                                primary amino group
# 408                                            antigen
# 409                     advanced glycation end-product
# 410  multinucleated neurons, anhydramnios, renal dy...
# 411                                          hepatitis
# 412                                           syndrome
# 413                                    gastroenteritis
# 414                  severe acute respiratory syndrome
# 415                                         bronchitis
# 416                                          influenza
# 417                                       glycoprotein
# 418                                 methylarsonic acid
# 419                                   ribonucleic acid
# 420                                   alpha-amino acid
# 421                                            protein
# 422                                         nucleotide
# 423                                               acid
# 424                      androsta-1,4-diene-3,17-dione
# 425                                primary amino group
# 426                                            antigen
# 427                     advanced glycation end-product
# 428  multinucleated neurons, anhydramnios, renal dy...
# 429                                          hepatitis
# 430                                           syndrome
# 431                                    gastroenteritis
# 432                  severe acute respiratory syndrome
# 433                                         bronchitis
# 434                                          influenza
# 435                                       glycoprotein
# 436                                 methylarsonic acid
# 437                                   ribonucleic acid
# 438                                   alpha-amino acid
# 439                                            protein
# 440                                         nucleotide
# 441                                               acid
# 442                      androsta-1,4-diene-3,17-dione
# 443                                primary amino group
# 444                                            antigen
# 445                     advanced glycation end-product
# 446  multinucleated neurons, anhydramnios, renal dy...
# 447                                          hepatitis
# 448                                           syndrome
# 449                                    gastroenteritis
# 450                  severe acute respiratory syndrome
# 451                                         bronchitis
# 452                                          influenza
# 453                                       glycoprotein
# 454                                 methylarsonic acid
# 455                                   ribonucleic acid
# 456                                   alpha-amino acid
# 457                                            protein
# 458                                         nucleotide
# 459                                               acid
# 460                      androsta-1,4-diene-3,17-dione
# 461                                primary amino group
# 462                                            antigen
# 463                     advanced glycation end-product
# 464  multinucleated neurons, anhydramnios, renal dy...
# 465                                          hepatitis
# 466                                           syndrome
# 467                                    gastroenteritis
# 468                  severe acute respiratory syndrome
# 469                                         bronchitis
# 470                                          influenza
# 471                                       glycoprotein
# 472                                 methylarsonic acid
# 473                                   ribonucleic acid
# 474                                   alpha-amino acid
# 475                                            protein
# 476                                         nucleotide
# 477                                               acid
# 478                      androsta-1,4-diene-3,17-dione
# 479                                primary amino group
# 480                                            antigen
# 481                     advanced glycation end-product
# 482  multinucleated neurons, anhydramnios, renal dy...
# 483                                          hepatitis
# 484                                           syndrome
# 485                                    gastroenteritis
# 486                  severe acute respiratory syndrome
# 487                                         bronchitis
# 488                                          influenza

# %%
# swap columns: rating 2 item_name
#df_with_user_id['rating'], df_with_user_id['item_name'] = df_with_user_id['item_name'], df_with_user_id['rating']
#df_with_user_id.rename(columns={'rating': 'item_name', 'item_name': 'rating'}, inplace = True)
path_to_cord_ds = '../data/results/comm_subset_cord-19_dataset.csv'
path_to_cord_userid = '../data/results/comm_subset_cord-19_dataset_userid.csv'
print('saving data')
save_final_data(data=df_with_user_id[['user', 'item', 'rating', 'item_name', 'year']], \
        path=path_to_cord_ds)
save_final_data(data=df_with_user_id[['user', 'author_name']], \
        path=path_to_cord_userid)
#save_final_data(data=df_with_user_id[['user', 'author_name', 'item', 'rating', 'item_name', 'year']], \
#        path=path_to_cord_userid)
# Out:
# saving data
